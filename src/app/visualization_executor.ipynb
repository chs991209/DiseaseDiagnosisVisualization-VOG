# %% [markdown]
# ## Main Executor of Visualization

# %%
import main_app

if __name__ == "__main__":
    try:
        # 1. 시스템이 스스로 데이터 디렉토리를 탐색
        target_directory = main_app.find_data_directory()

        # 2. 퍼사드 파이프라인 가동
        pipeline = main_app.VOGPipelineFacade()
        pipeline.process_directory(target_directory)

    except Exception as e:
        print(f"[System Error] 파이프라인 초기화 중 문제가 발생했습니다: {e}")
